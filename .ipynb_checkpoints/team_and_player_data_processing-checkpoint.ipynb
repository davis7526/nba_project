# %%
import pandas as pd
import numpy as np
import time
import nba_api


from nba_api.stats.static import players
from nba_api.stats.static import teams

from nba_api.stats.endpoints import playercareerstats
from nba_api.stats.endpoints import teamyearbyyearstats
from nba_api.stats.endpoints import playerdashboardbyyearoveryear
##from fastparquet import ParquetFile
from nba_api.stats.endpoints import leaguedashteamstats
from nba_api.stats.endpoints import leaguedashplayerstats
from nba_api.stats.endpoints import commonplayerinfo

# %%
player_position
# Out:
#     PERSON_ID FIRST_NAME     LAST_NAME   DISPLAY_FIRST_LAST  \
# 0       76001       Alaa     Abdelnaby       Alaa Abdelnaby
# 0       76002       Zaid    Abdul-Aziz      Zaid Abdul-Aziz
# 0       76003     Kareem  Abdul-Jabbar  Kareem Abdul-Jabbar
# 0          51    Mahmoud    Abdul-Rauf   Mahmoud Abdul-Rauf
# 0        1505      Tariq   Abdul-Wahad    Tariq Abdul-Wahad
# ..        ...        ...           ...                  ...
# 0       77984       Rick         Robey           Rick Robey
# 0        2774    Bernard      Robinson     Bernard Robinson
# 0         997      Chris      Robinson       Chris Robinson
# 0       77986   Cliff T.      Robinson    Cliff T. Robinson
# 0         361   Clifford      Robinson    Clifford Robinson
#
#    DISPLAY_LAST_COMMA_FIRST  DISPLAY_FI_LAST          PLAYER_SLUG  \
# 0           Abdelnaby, Alaa     A. Abdelnaby       alaa-abdelnaby
# 0          Abdul-Aziz, Zaid    Z. Abdul-Aziz      zaid-abdul-aziz
# 0      Abdul-Jabbar, Kareem  K. Abdul-Jabbar  kareem-abdul-jabbar
# 0       Abdul-Rauf, Mahmoud    M. Abdul-Rauf   mahmoud-abdul-rauf
# 0        Abdul-Wahad, Tariq   T. Abdul-Wahad    tariq-abdul-wahad
# ..                      ...              ...                  ...
# 0               Robey, Rick         R. Robey           rick-robey
# 0         Robinson, Bernard      B. Robinson     bernard-robinson
# 0           Robinson, Chris      C. Robinson       chris-robinson
# 0        Robinson, Cliff T.      C. Robinson     cliff-t-robinson
# 0        Robinson, Clifford      C. Robinson    clifford-robinson
#
#               BIRTHDATE               SCHOOL COUNTRY  ...  \
# 0   1968-06-24T00:00:00                 Duke     USA  ...
# 0   1946-04-07T00:00:00           Iowa State     USA  ...
# 0   1947-04-16T00:00:00                 UCLA     USA  ...
# 0   1969-03-09T00:00:00      Louisiana State     USA  ...
# 0   1974-11-03T00:00:00       San Jose State  France  ...
# ..                  ...                  ...     ...  ...
# 0   1956-01-30T00:00:00             Kentucky     USA  ...
# 0   1980-12-26T00:00:00             Michigan     USA  ...
# 0   1974-04-02T00:00:00     Western Kentucky     USA  ...
# 0   1960-03-13T00:00:00  Southern California     USA  ...
# 0   1966-12-16T00:00:00          Connecticut     USA  ...
#
#                      PLAYERCODE FROM_YEAR TO_YEAR  DLEAGUE_FLAG NBA_FLAG  \
# 0        HISTADD_alaa_abdelnaby      1990    1994             N        Y
# 0       HISTADD_zaid_abdul-aziz      1968    1977             N        Y
# 0   HISTADD_kareem_abdul-jabbar      1969    1988             N        Y
# 0            mahmoud_abdul-rauf      1990    2000             N        Y
# 0             tariq_abdul-wahad      1997    2003             N        Y
# ..                          ...       ...     ...           ...      ...
# 0            HISTADD_rick_robey      1978    1985             N        Y
# 0              bernard_robinson      2004    2006             N        Y
# 0                chris_robinson      1996    1997             N        Y
# 0      HISTADD_cliff_t_robinson      1979    1991             N        Y
# 0             clifford_robinson      1989    2006             N        Y
#
#    GAMES_PLAYED_FLAG DRAFT_YEAR DRAFT_ROUND  DRAFT_NUMBER GREATEST_75_FLAG
# 0                  Y       1990           1            25                N
# 0                  Y       1968           1             5                N
# 0                  Y       1969           1             1                Y
# 0                  Y       1990           1             3                N
# 0                  Y       1997           1            11                N
# ..               ...        ...         ...           ...              ...
# 0                  Y       1978           1             3                N
# 0                  Y       2004           2            45                N
# 0                  Y       1996           2            51                N
# 0                  Y       1979           1            11                N
# 0                  Y       1989           2            36                N
#
# [3402 rows x 33 columns]

# %%
#Get a DataFrame of all active NBA players and their ID's
nba_players = pd.json_normalize(players.get_active_players())

#Initialize a DataFrame to store all players career stats
career_stats_by_season = pd.DataFrame()

#Get a DataFrame of all teams and their ID's
nba_teams = pd.json_normalize(teams.get_teams())

#Initialize a DataFrame to store all teams season stats
team_stats_by_season = pd.DataFrame()

# %%
#Pulling NBA players historical data
seasons = ['2021-22', '2020-21','2019-20','2018-19','2017-18','2016-17','2015-16','2014-15','2013-14','2012-13',
           '2011-12','2010-11','2009-10','2008-09','2007-08','2006-07','2005-06','2004-05','2003-04','2002-03','2001-02',
          '2000-01','1999-00','1998-99','1997-98','1996-97']
for s_id in seasons:
    player_season_stats = leaguedashplayerstats.LeagueDashPlayerStats(measure_type_detailed_defense = 'Advanced', 
                                        season_type_all_star = 'Regular Season', season = s_id).get_data_frames()[0]
    player_season_stats['SEASON'] = s_id
    time.sleep(10)
    
    career_stats_by_season = career_stats_by_season.append(player_season_stats)
    career_stats_by_season = career_stats_by_season.reset_index(drop = True)

# %%
career_stats_by_season.to_parquet('players_stats_by_season.parquet')

# %%
#Pulling NBA teams historical data
seasons = ['2021-22', '2020-21','2019-20','2018-19','2017-18','2016-17','2015-16','2014-15','2013-14','2012-13',
           '2011-12','2010-11','2009-10','2008-09','2007-08','2006-07','2005-06','2004-05','2003-04','2002-03','2001-02',
          '2000-01','1999-00','1998-99','1997-98','1996-97']
for s_id in seasons:
    team_season_stats = leaguedashteamstats.LeagueDashTeamStats(measure_type_detailed_defense = 'Advanced', 
                                        season_type_all_star = 'Regular Season', season = s_id).get_data_frames()[0]
    team_season_stats['SEASON'] = s_id
    time.sleep(10)
    
    team_stats_by_season = team_stats_by_season.append(team_season_stats)
team_stats_by_season = team_stats_by_season.reset_index(drop = True)

# %%
#Team Data Processing

#Save Teams Data as Parquet File
team_stats_by_season.to_parquet('team_stats_by_season.parquet')

# %%
team_stats_by_season
# Out:
#         TEAM_ID            TEAM_NAME  GP   W   L  W_PCT     MIN  E_OFF_RATING  \
# 0    1610612737        Atlanta Hawks  82  43  39  0.524  3941.0         114.0
# 1    1610612738       Boston Celtics  82  51  31  0.622  3981.0         112.1
# 2    1610612751        Brooklyn Nets  82  44  38  0.537  3951.0         111.0
# 3    1610612766    Charlotte Hornets  82  43  39  0.524  3976.0         111.7
# 4    1610612741        Chicago Bulls  82  46  36  0.561  3946.0         111.0
# ..          ...                  ...  ..  ..  ..    ...     ...           ...
# 767  1610612760  Seattle SuperSonics  82  57  25  0.695  3956.0         108.2
# 768  1610612761      Toronto Raptors  82  30  52  0.366  3966.0         101.3
# 769  1610612762            Utah Jazz  82  64  18  0.780  3966.0         110.5
# 770  1610612763  Vancouver Grizzlies  82  14  68  0.171  3956.0          97.6
# 771  1610612764   Washington Bullets  82  44  38  0.537  3971.0         104.1
#
#      OFF_RATING  E_DEF_RATING  ...  DREB_PCT_RANK  REB_PCT_RANK  \
# 0         115.4         112.1  ...             12            14
# 1         113.6         104.0  ...             16            10
# 2         113.2         109.6  ...             30            15
# 3         113.6         111.0  ...             29            27
# 4         112.7         111.1  ...              7            17
# ..          ...           ...  ...            ...           ...
# 767       109.6          99.5  ...             21            15
# 768       102.9         105.1  ...             20            17
# 769       112.4         101.6  ...              4             4
# 770        99.1         108.9  ...             29            29
# 771       105.2         102.0  ...              7            11
#
#      TM_TOV_PCT_RANK  EFG_PCT_RANK  TS_PCT_RANK  PACE_RANK  PIE_RANK  CFID  \
# 0                  1             8            6         17        14    10
# 1                 13             9            9         24         2    10
# 2                 18            11           11         11        11    10
# 3                  9             7           13          5        15    10
# 4                  6            10            8         14        20    10
# ..               ...           ...          ...        ...       ...   ...
# 767                6             6            4         16         3    10
# 768               22            22           23         14        21    10
# 769               10             1            1         18         1    10
# 770               20            26           28         24        29    10
# 771                9             9           14          7        12    10
#
#                 CFPARAMS   SEASON
# 0          Atlanta Hawks  2021-22
# 1         Boston Celtics  2021-22
# 2          Brooklyn Nets  2021-22
# 3      Charlotte Hornets  2021-22
# 4          Chicago Bulls  2021-22
# ..                   ...      ...
# 767  Seattle SuperSonics  1996-97
# 768      Toronto Raptors  1996-97
# 769            Utah Jazz  1996-97
# 770  Vancouver Grizzlies  1996-97
# 771   Washington Bullets  1996-97
#
# [772 rows x 49 columns]

# %%
# Out:
#        TEAM_ID               TEAM_NAME  GP   W   L  W_PCT     MIN  \
# 15         111.2       113.0         106.3  ...             10              9
# 16         112.5       114.3         109.4  ...             16              2
# 17         111.3       113.8         109.1  ...              7             28
# 18         109.0       111.2         110.5  ...              4              3
# 19         108.0       109.7         107.6  ...              6              4
# 20         102.2       103.8         110.2  ...             24             14
# 21         101.8       103.9         110.3  ...             27              8
# 22         111.0       113.0         108.3  ...             30             19
# 23         112.5       114.2         104.7  ...             21             13
# 24         105.5       107.3         114.0  ...             18             20
# 25         107.2       109.6         112.9  ...             22             22
# 26         109.4       111.9         110.0  ...              8             24
# 27         109.6       112.1         107.9  ...              2             23
# 28         114.0       116.2         107.7  ...              5              5
# 29         108.9       110.2         111.7  ...             29             11
#
#     REB_PCT_RANK  TM_TOV_PCT_RANK  EFG_PCT_RANK  TS_PCT_RANK  PACE_RANK  \
# 0             14                1             8            6         17
# 1             10               13             9            9         24
# 2             15               18            11           11         11
# 3             27                9             7           13          5
# 4             17                6            10            8         14
# 5             12               27            14           15         25
# 6             16                7            13           14         30
# 7              4               26             1            1         20
# 8             30               20            30           29         13
# 9              8               29             3            4         15
# 10            28               30            17           18          2
# 11             7               24            20           20         18
# 12            26               14            19           19         19
# 13            22               19            15           17          7
# 14             1                8            23           24          4
# 15             9               28             5            3         28
# 16             6               10             6            7          3
# 17            21               17            12           12          1
# 18             3               21            24           22         21
# 19             5               12            26           25         29
# 20            24               15            29           30         12
# 21            23               23            28           28         10
# 22            20                5            16           10         26
# 23            13                4             4            5          8
# 24            25               25            25           26         15
# 25            29               16            22           21          9
# 26            18                2            21           23          6
# 27            11                3            27           27         27
# 28             2               22             2            2         23
# 29            19               11            18           16         22
#
#     PIE_RANK  CFID                CFPARAMS
# 0         14    10           Atlanta Hawks
# 1          2    10          Boston Celtics
# 2         11    10           Brooklyn Nets
# 3         15    10       Charlotte Hornets
# 4         20    10           Chicago Bulls
# 5          7    10     Cleveland Cavaliers
# 6         12    10        Dallas Mavericks
# 7          9    10          Denver Nuggets
# 8         29    10         Detroit Pistons
# 9          3    10   Golden State Warriors
# 10        28    10         Houston Rockets
# 11        24    10          Indiana Pacers
# 12        17    10             LA Clippers
# 13        23    10      Los Angeles Lakers
# 14         4    10       Memphis Grizzlies
# 15         5    10              Miami Heat
# 16        10    10         Milwaukee Bucks
# 17        16    10  Minnesota Timberwolves
# 18        18    10    New Orleans Pelicans
# 19        22    10         New York Knicks
# 20        27    10   Oklahoma City Thunder
# 21        26    10           Orlando Magic
# 22         8    10      Philadelphia 76ers
# 23         1    10            Phoenix Suns
# 24        30    10  Portland Trail Blazers
# 25        25    10        Sacramento Kings
# 26        13    10       San Antonio Spurs
# 27        21    10         Toronto Raptors
# 28         6    10               Utah Jazz
# 29        19    10      Washington Wizards
#
# [30 rows x 48 columns]
